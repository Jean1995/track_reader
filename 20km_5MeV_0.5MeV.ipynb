# %%
from scripts import *

# %% [markdown]
# * injection height: 20 km
# * initial energy: 5 MeV
# * cut energy: 0.5 MeV

# %%
PATH_C7 = "data_20km_5MeV_0.5MeV/TRACK_pt.dat"
PATH_C8_02 = "data_20km_5MeV_0.5MeV/C8_0.2.parquet"
PATH_C8_01 = "data_20km_5MeV_0.5MeV/C8_0.1.parquet"
PATH_C8_001 = "data_20km_5MeV_0.5MeV/C8_0.01.parquet"

# %%
C7_3d_plots(PATH_C7, 'CORSIKA 7')
# Out:
# Tracks found in: data_20km_5MeV_0.5MeV/TRACK_pt.dat
# Max energy (kinetic): 0.005 GeV, Min energy (kinetic): 0.0010099989299999998 GeV

# %%
C8_3d_plots(PATH_C8_02, 'CORSIKA 8, maxRadians=0.2')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004997774376533926 GeV

# %%
C8_3d_plots(PATH_C8_01, 'CORSIKA 8, maxRadians=0.1')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004998748190701008 GeV

# %%
C8_3d_plots(PATH_C8_001, 'CORSIKA 8, maxRadians=0.01')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004998981603421271 GeV

# %%
C7_tz_plots(PATH_C7, "CORSIKA 7")
# Out:
# Tracks found in: data_20km_5MeV_0.5MeV/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.0010099989299999998 GeV
# Overall number of steps: 74

# %%
C8_tz_plots(PATH_C8_02, 'CORSIKA 8, maxRadians=0.2')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004997774376533926 GeV
# Overall number of steps: 171

# %%
C8_tz_plots(PATH_C8_01, 'CORSIKA 8, maxRadians=0.1')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004998748190701008 GeV
# Overall number of steps: 190

# %%
C8_tz_plots(PATH_C8_001, 'CORSIKA 8, maxRadians=0.01')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004998981603421271 GeV
# Overall number of steps: 2195

# %%
C7_xy_plots(PATH_C7, 'CORSIKA 7')
# Out:
# Tracks found in: data_20km_5MeV_0.5MeV/TRACK_pt.dat
# Max energy (kinetic): 0.005 GeV, Min energy (kinetic): 0.0010099989299999998 GeV

# %%
C8_xy_plots(PATH_C8_02, 'CORSIKA 8, maxRadians=0.2')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004997774376533926 GeV

# %%
C8_xy_plots(PATH_C8_01, 'CORSIKA 8, maxRadians=0.1')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004998748190701008 GeV

# %%
C8_xy_plots(PATH_C8_001, 'CORSIKA 8, maxRadians=0.01')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.0004998981603421271 GeV
