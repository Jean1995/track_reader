# %%
from scripts import *

# %%
PATH1 = "/mnt/c/Users/Jean-Marco/CLionProjects/corsika/cmake-build-relwithdebinfo/bin/no_interaction_0.2_limited/tracks/tracks.parquet"
PATH2 = "/mnt/c/Users/Jean-Marco/CLionProjects/corsika/cmake-build-relwithdebinfo/bin/no_interaction_0.01_limited/tracks/tracks.parquet"
PATH3 = "/mnt/c/Users/Jean-Marco/CLionProjects/corsika/cmake-build-relwithdebinfo/bin/no_interaction_0.1_limited/tracks/tracks.parquet"
PATH4 = "/mnt/c/Users/Jean-Marco/CLionProjects/corsika/cmake-build-relwithdebinfo/bin/no_interaction_0.001_limited/tracks/tracks.parquet"

# %%
C8_tz_plots(PATH1, 'maxRadians=0.2')
C8_tz_plots(PATH3, 'maxRadians=0.1')
C8_tz_plots(PATH2, 'maxRadians=0.01')
C8_tz_plots(PATH4, 'maxRadians=0.001')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 241
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 506
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 8642
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 99167

# %%
C8_zy_plots(PATH1, 'maxRadians=0.2')
plt.xlim(45000, 50000)
C8_zy_plots(PATH3, 'maxRadians=0.1')
plt.xlim(45000, 50000)
C8_zy_plots(PATH2, 'maxRadians=0.01')
plt.xlim(45000, 50000)
C8_zy_plots(PATH4, 'maxRadians=0.001')
plt.xlim(45000, 50000)
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 241
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 506
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 8642
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 99167
# (45000.0, 50000.0)

# %%
C8_xy_plots(PATH1, 'maxRadians=0.2')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 241

# %%
C8_xy_plots(PATH3, 'maxRadians=0.1')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 506

# %%
C8_xy_plots(PATH2, 'maxRadians=0.01')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 8642

# %%
C8_xy_plots(PATH4, 'maxRadians=0.001')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 99167

# %%
C8_xy_plots(PATH1, 'maxRadians=0.2')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 22085

# %%
C8_xy_plots(PATH3, 'maxRadians=0.1')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 43323

# %%
C8_xy_plots(PATH2, 'maxRadians=0.01')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 17458

# %%
C8_xy_plots(PATH4, 'maxRadians=0.001')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 201259
