# %%
from scripts import *

# %%
PATH1 = "/mnt/c/Users/Jean-Marco/CLionProjects/corsika/cmake-build-relwithdebinfo/bin/no_interaction_0.2_onlyx/tracks/tracks.parquet"
PATH2 = "/mnt/c/Users/Jean-Marco/CLionProjects/corsika/cmake-build-relwithdebinfo/bin/no_interaction_0.01_onlyx/tracks/tracks.parquet"
PATH3 = "/mnt/c/Users/Jean-Marco/CLionProjects/corsika/cmake-build-relwithdebinfo/bin/no_interaction_0.1_onlyx/tracks/tracks.parquet"
PATH4 = "/mnt/c/Users/Jean-Marco/CLionProjects/corsika/cmake-build-relwithdebinfo/bin/no_interaction_0.001_onlyx/tracks/tracks.parquet"

# %%
B = 20.4e-6
m = 9.1093837e-31 # electron mass in kg
q = 1.60217663e-19 # electron charge in coloumb
E = 5 # MeV
m_MeV = 0.5109989461 # electron mass in MeV
p = np.sqrt(E**2 - m_MeV**2) # p in MeV
c = 299_792_458
v = c * p / E
beta = v / c
gamma = 1 / np.sqrt(1 - beta**2)
print(v/c)
print(m)
print(q)
print(B)
r = m * v * gamma / (q * B)
print(r) # in m
# Out:
# 0.9947638931341384
# 9.1093837e-31
# 1.60217663e-19
# 2.04e-05
# 813.2782383647893

# %%
B = 20.4e-6
m = 9.1093837e-31 # electron mass in kg
q = 1.60217663e-19 # electron charge in coloumb
E = 5e6 * 1.60218e-19 # 5 MeV in J
c = 299_792_458
p = np.sqrt(E**2 - (m * c**2)**2)/c
r = p / (q * B)
print(r) # in m
center = 50000
# Out:
# 813.2799588778723

# %%
C8_tz_plots(PATH1, 'maxRadians=0.2')
C8_tz_plots(PATH3, 'maxRadians=0.1')
C8_tz_plots(PATH2, 'maxRadians=0.01')
C8_tz_plots(PATH4, 'maxRadians=0.001')
plt.axhline(y = center-r, linestyle='dashed', color='black')
plt.axhline(y = center+r, linestyle='dashed', color='black', label='expected gyroradius')
plt.legend()
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 95
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 185
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 1834
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 18335

# %%
#C8_zy_plots(PATH1, 'maxRadians=0.2')
C8_zy_plots(PATH3, 'maxRadians=0.1')
C8_zy_plots(PATH2, 'maxRadians=0.01')
C8_zy_plots(PATH4, 'maxRadians=0.001')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 185
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 1834
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 18335

# %%
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 201259

# %%
C8_xy_plots(PATH1, 'maxRadians=0.2')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 9417

# %%
C8_xy_plots(PATH3, 'maxRadians=0.1')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 43323

# %%
C8_xy_plots(PATH2, 'maxRadians=0.01')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 17458

# %%
C8_xy_plots(PATH4, 'maxRadians=0.001')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 201259

# %%
C8_xy_plots(PATH1, 'maxRadians=0.2')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 22085

# %%
C8_xy_plots(PATH3, 'maxRadians=0.1')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 43323

# %%
C8_xy_plots(PATH2, 'maxRadians=0.01')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 17458

# %%
C8_xy_plots(PATH4, 'maxRadians=0.001')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.004488999955356121 GeV
# Overall number of steps: 201259
