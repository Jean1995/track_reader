# %%
from scripts import *

# %% [markdown]
# * injection height: 50 km
# * initial energy: 5 MeV
# * cut energy: 0.5 MeV
# * max_rad: 0.01

# %%
PATH_C8 = "data_50km_5MeV_0.5MeV/C8_0.01_validation.parquet"

# %%
PATH_C8_noscatter = "data_50km_5MeV_0.5MeV/C8_0.01_noscattering.parquet"

# %%
C8_3d_plots(PATH_C8, 'CORSIKA 8, maxRadians=0.01')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.000499898917041719 GeV
# Overall number of steps: 31255

# %%
C8_3d_plots(PATH_C8_noscatter, 'CORSIKA 8, maxRadians=0.01, noScattering')
# Out:
# Max energy (kinetic): 0.004488999955356121 GeV, Min energy (kinetic): 0.000499898917041719 GeV
# Overall number of steps: 31255

# %%
C8_tz_plots(PATH_C8, 'CORSIKA 8, maxRadians=0.01')

# %%
C8_tz_plots(PATH_C8_noscatter, 'CORSIKA 8, maxRadians=0.01, noScattering')
