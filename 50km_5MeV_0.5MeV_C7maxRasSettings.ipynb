# %%
from scripts import *

# %% [markdown]
# * injection height: 50 km
# * initial energy: 5 MeV
# * cut energy: 0.5 MeV
#
# I am looking at different 'maxRadian' settings for CORSIKA 7 by manually changing the 'BLIMIT' parameter within corsika.F

# %%
PATH_C7_02 = "data_50km_C7_different_maxRad/maxRad0.2/TRACK_pt.dat"
PATH_C7_01 = "data_50km_C7_different_maxRad/maxRad0.1/TRACK_pt.dat"
PATH_C7_001 = "data_50km_C7_different_maxRad/maxRad0.01/TRACK_pt.dat"

# %% [markdown]
# ### 3D Plots

# %%
C7_3d_plots(PATH_C7_02, 'CORSIKA 7, maxRad 0.2')
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.2/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.00100999893 GeV
# Overall number of steps: 2979

# %%
C7_3d_plots(PATH_C7_01, 'CORSIKA 7, maxRad 0.1')
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.1/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.00100999893 GeV
# Overall number of steps: 6433

# %%
C7_3d_plots(PATH_C7_001, 'CORSIKA 7, maxRad 0.01')
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.01/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.0005012993978415767 GeV
# Overall number of steps: 64658

# %%
C7_tz_plots(PATH_C7_02, "CORSIKA 7, maxRad 0.2")
plt.ylim(40000, 50000)
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.2/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.00100999893 GeV
# Overall number of steps: 2979
# (40000.0, 50000.0)

# %%
C7_tz_plots(PATH_C7_01, "CORSIKA 7, maxRad 0.1")
plt.ylim(40000, 50000)
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.1/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.00100999893 GeV
# Overall number of steps: 6433
# (40000.0, 50000.0)

# %%
C7_tz_plots(PATH_C7_001, "CORSIKA 7, maxRad 0.01")
plt.ylim(40000, 50000)
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.01/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.0005012993978415767 GeV
# Overall number of steps: 64658
# (40000.0, 50000.0)

# %%
C7_xy_plots(PATH_C7_02, "CORSIKA 7, maxRad 0.2")
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.2/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.00100999893 GeV
# Overall number of steps: 2979

# %%
C7_xy_plots(PATH_C7_01, "CORSIKA 7, maxRad 0.1")
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.1/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.00100999893 GeV
# Overall number of steps: 6433

# %%
C7_xy_plots(PATH_C7_001, "CORSIKA 7, maxRad 0.01")
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.01/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.0005012993978415767 GeV
# Overall number of steps: 64658

# %%
C7_zx_plots(PATH_C7_02, "CORSIKA 7, maxRad 0.2")
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.2/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.00100999893 GeV
# Overall number of steps: 2979

# %%
C7_zx_plots(PATH_C7_01, "CORSIKA 7, maxRad 0.1")
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.1/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.00100999893 GeV
# Overall number of steps: 6433

# %%
C7_zx_plots(PATH_C7_001, "CORSIKA 7, maxRad 0.01")
# Out:
# Tracks found in: data_50km_C7_different_maxRad/maxRad0.01/TRACK_pt.dat
# Max energy (total): 0.005 GeV, Min energy (total): 0.0005012993978415767 GeV
# Overall number of steps: 64658
